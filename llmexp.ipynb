# %% [markdown]
# # Gemini

# %%
import google.generativeai as genai
import os

# Configure your API key
# It's recommended to store your API key as an environment variable
genai.configure(api_key="AIzaSyAYZ2I1UTVUWtX673xvAZ0T--omaUd82iQ")

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.5-flash')

# Generate text from a simple prompt
prompt = "Explain how AI works in a few words."
response = model.generate_content(prompt)
print(response.text)

# %% [markdown]
# # GPT

# %%
import requests
import json

url = "https://api.openai.com/v1/chat/completions"
api_key = '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'

textprompt= "Explain how AI works in a few words."
payload = json.dumps({
"model": "gpt-5.2",
"messages": [
    {
        "role": "user",
        "content": textprompt
    }
]
})
headers = {
'Accept': 'application/json',
'Authorization': f'Bearer {api_key}',
'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.json())
